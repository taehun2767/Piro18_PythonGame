# %%
# %pip install selenium
import selenium
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# %pip install pandas
import pandas as pd

# %pip install requests
import requests

from bs4 import BeautifulSoup
from itertools import repeat
from pprint import pprint
import time

#맥 m1에서 사용하기 위해
# %pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())


driver = webdriver.Chrome()
#화면이 작을 경우 잘리는 데이터가 있을 수 있으므로 화면 크기 Max
driver.maximize_window()

driver.get('https://www.melon.com/index.htm')
time.sleep(2)
#게임에 불러올 가수 데이터
singerList = ['블랙핑크', '르세라핌', '뉴진스', '아이브', '데이식스']
#가수별로 받아올 노래 데이터
singer_song_list = []

for i in singerList:
    #검색창에 순서대로 가수 입력
    elemSearch = driver.find_element('id','top_search')
    elemSearch.send_keys(i)
    #검색버튼 누르기
    elem = driver.find_element(By.CLASS_NAME, 'search_m')
    elem.click()
    time.sleep(1)

    #태그 중 곡 리스트 카테고리 들어가기
    elem = driver.find_element(By.LINK_TEXT, '곡')
    elem.click()
    time.sleep(1)

    #가수 제목 리스트에 미리 추가
    singer_song_list.append(i)
    #첫 번째 페이지의 노래 제목들 리스트
    elem = driver.find_elements(By.CSS_SELECTOR, '#frm_defaultList > div > table > tbody > tr > td:nth-child(3) > div > div > a.fc_gray')
    #리스트 안에서 노래 하나씩 뽑아서 전체 데이터에 추가
    for e in elem:
        linkText = e.get_property('textContent')
        #회색처리 된 부분 제외
        if linkText != None:
            #괄호 안의 정보 제거
            if '(' in linkText:
                linkText = linkText[:linkText.index('(')]
                singer_song_list.append({i : linkText,})
            else:
                singer_song_list.append({i : linkText,})

    #두 번째 페이지부터는 for문으로 돌리기 
    pages = driver.find_elements(By.CSS_SELECTOR, '#pageObjNavgation > div > span > *')
    for j in range(2, len(pages)+1):
        elem = driver.find_element(By.CSS_SELECTOR, '#pageObjNavgation > div > span > a:nth-child({})'.format(j))
        elem.click()
        time.sleep(2)
        elem = driver.find_elements(By.CSS_SELECTOR, '#frm_defaultList > div > table > tbody > tr > td:nth-child(3) > div > div > a.fc_gray')
        for e in elem:
            linkText = e.get_property('textContent')
            if linkText != None:
                if '(' in linkText:
                    linkText = linkText[:linkText.index('(')]
                    singer_song_list.append({i : linkText,})
                else:
                    singer_song_list.append({i : linkText,})

    #검색어 초기화
    searchBox = driver.find_element(By.XPATH, '//*[@id="top_search"]')
    searchBox.clear()

    #pandas를 통해서 데이터 저장
    df = pd.DataFrame(singer_song_list)
    df.to_csv("singer_song_list.csv")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in /Users/seojin/Library/Python/3.9/lib/python/site-packages (4.7.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from selenium) (1.26.13)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: outcome in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/seojin/Library/Python/3.9/lib/python/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/seojin/Library/Python/3.9/lib/python/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests) (2022.12.7)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: webdriver-manager in /Users/seojin/Library/Python/3.9/lib/python/site-packages (3.8.5)
# Requirement already satisfied: requests in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: python-dotenv in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: tqdm in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: packaging in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from webdriver-manager) (22.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests->webdriver-manager) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests->webdriver-manager) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/seojin/Library/Python/3.9/lib/python/site-packages (from requests->webdriver-manager) (2.1.1)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# /var/folders/jg/xn7ncghj3xb8_n7z5kml0yk00000gp/T/ipykernel_75645/1468936700.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
